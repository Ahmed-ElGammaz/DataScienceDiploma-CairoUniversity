# %% [markdown]
# ### STUDENT CODE: 202200009

# %% [markdown]
# ### The first exercise

# %% [markdown]
# ![lecture-02-01.jpg](attachment:lecture-02-01.jpg)

# %% [markdown]
# #### a)

# %%
import numpy as np

# %%
A= np.array([[3,4,3],[5,6,0],[2,9,4],[1,1,7]])
A
# Out:
# array([[3, 4, 3],
#        [5, 6, 0],
#        [2, 9, 4],
#        [1, 1, 7]])

# %%
A.shape
# Out:
# (4, 3)

# %%
B= np.array([[1],[2],[3]])
B
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
B.shape
# Out:
# (3, 1)

# %% [markdown]
# #### b)

# %%
AB = np.dot(A,B)
AB
# Out:
# array([[20],
#        [17],
#        [32],
#        [24]])

# %% [markdown]
# ### This information represents the total costs of products 20, 17, 32, and 24 in January, February, March, and April, respectively.
# ------------------------------------------------------------------

# %% [markdown]
# ### The second exercise

# %% [markdown]
# ![lecture-02-02.jpg](attachment:lecture-02-02.jpg)

# %%
M= np.array([[45,60,75],[30,30,40],[12,65,45],[15,40,35]])
M
# Out:
# array([[45, 60, 75],
#        [30, 30, 40],
#        [12, 65, 45],
#        [15, 40, 35]])

# %%
J= np.array([[30,33,40],[21,23,25],[9,12,11],[8,10,9]])
J
# Out:
# array([[30, 33, 40],
#        [21, 23, 25],
#        [ 9, 12, 11],
#        [ 8, 10,  9]])

# %% [markdown]
# #### a)

# %%
totalSalesInMayAndJune = M + J
totalSalesInMayAndJune
# Out:
# array([[ 75,  93, 115],
#        [ 51,  53,  65],
#        [ 21,  77,  56],
#        [ 23,  50,  44]])

# %% [markdown]
# ##### b)

# %%
maySalesSubtractionJuneSales=  M - J
maySalesSubtractionJuneSales
# Out:
# array([[15, 27, 35],
#        [ 9,  7, 15],
#        [ 3, 53, 34],
#        [ 7, 30, 26]])

# %%
#c)
x = np . array ([[1], [1], [1]])
x
# Out:
# array([[1],
#        [1],
#        [1]])

# %%
Mx = np.dot(M,x)
Mx
# Out:
# array([[180],
#        [100],
#        [122],
#        [ 90]])

# %% [markdown]
# #### This information represents the total sales in May 180, 100, 122, and 90 of shirts, jeans, suits, and raincoats, respectively.
# -------------------------------------------------------------

# %% [markdown]
# #### d)

# %%
y = np.array([[1,1,1,1]])

# %%
yM = np.dot(y,M)
yM
# Out:
# array([[102, 195, 195]])

# %% [markdown]
# #### This information represents the total sales in May 102, 195, and 195 of small, medium, and large, respectively.
# -------------------------------------------

# %% [markdown]
# #### e)

# %%
yMx= np.dot(yM,x)
yMx
# Out:
# array([[492]])

# %% [markdown]
# #### This information represents the total sales in May is 492.
# ----------------------------------------------------------

# %% [markdown]
# ## Best regards to you
